# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
###### 作業一 #######
# Dataset: Black Friday
1.	你選的這組資料為何重要
通過消費者行為進行銷售研究。
2.	資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
提供者：Kaggle，方式蒐集：於黑色星期五時，在不同零售商店收集相關商品販賣數據。
3.	蒐集而來的資料型態為何
User_ID (User)
Product_ID
Gender (Boolean)
Age (Age in bins)
Occupation
City_Category
Stay_In_Current_City_Years
Marital_Status
Product_Category_1
Product_Category_2
Product_Category_3
Purchase (Purchase amount in dollar)
4.	這組資料想解決的問題如何評估
在Black Friday時，藉由大家所購買的商品行為來決定當日該販賣何商品，進而增加營業額。

# %%
###### 作業二 #######
想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：

1.	核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
a.	提升業績：
(1)	用一些折扣方式或是活動，使得顧客搭乘意願提升。
(2)	於某些客源量較多路段，定點載客。
b.	假設：不同族群或天氣或地點是否影響載客人數。
2.	資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
a.	影響：
(1)	不同的節日或時間可能一時提升當日或某時段之業績，但對於整體業績提升來說，較無影響。
(2)	不同宣傳方式或是折扣方式也會影響某時段之業績。
b.	資料如何蒐集：紀錄每台車的每位客人叫車所使用方式、地點、路程遠近、日期時間、天氣。
3.	蒐集而來的資料型態為何
ID (Custom)
日期 (月/日/年)
時間 (時:分)
性別
年齡
天氣
車號
叫車方式 (網路、電話、App、其他)
地點 (縣市路段)
路程 (多遠距離)
會員 (加入會員與否)
宣傳方式 (得知此載客車隊之途徑)
4.	你要回答的問題，其如何評估 (tips：你的假設如何驗證)
a.	於不同地點先派駐幾台車，並看其客源量多寡，調整派駐車輛。
b.	不同天氣看每輛車的載客情況，藉由判斷天氣對業績之影響。
c.	看族群的情況對業績的影響，可能高年齡者較常叫車。

# %%
###### 作業三 ######
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, yp):
    """
    請完成這個 Function 後往下執行
    """
    mse = MSE = sum((y - yp)**2) / len(y)
    return mse

def mean_absolute_error(y, yp):
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 251.910
# The Mean absolute error is 12.366
